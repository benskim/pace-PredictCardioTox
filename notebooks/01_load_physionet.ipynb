# %% [markdown]
# # 01 — Load PhysioNet QT Database
#
# Download a small validation subset of the PhysioNet QT Database and load record signals plus annotations.

# %%
from pathlib import Path

from ecg_analytics.physionet import (
    discover_local_records,
    download_qt_database,
    load_qt_annotations,
    load_qt_record,
)

DATA_DIR = Path('data/physionet')
RECORDS = ['sel100']
ANNOTATORS = ['pu0']

# %% [markdown]
# ## Download validation data
#
# Run this cell when network access is available. Skip it if the records already exist under `data/physionet/qtdb`.

# %%
# download_qt_database(DATA_DIR, records=RECORDS, annotators=ANNOTATORS)
print('Local records:', discover_local_records(DATA_DIR))

# %% [markdown]
# ## Load one record

# %%
record_name = RECORDS[0]
# signals, metadata = load_qt_record(record_name, DATA_DIR)
# annotations = load_qt_annotations(record_name, ANNOTATORS[0], DATA_DIR)
# display(metadata)
# display(signals.head())
# display(annotations.head())
